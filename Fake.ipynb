# %%
# Importing necessary libraries

import pandas as pd

# %%
# Connecting google drive to colab to fetch data

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Creating a dataframe consisting of  data for Original and Fake reviews

df = pd.read_csv('/content/drive/MyDrive/Tourist_Data/fake reviews dataset.csv')

# %%
df

#Here OR==> Original review given by a user
#CG ==> Reviews generated by a computer
# Out:
#                            category  rating label  \
# 0                Home_and_Kitchen_5     5.0    CG
# 1                Home_and_Kitchen_5     5.0    CG
# 2                Home_and_Kitchen_5     5.0    CG
# 3                Home_and_Kitchen_5     1.0    CG
# 4                Home_and_Kitchen_5     5.0    CG
# ...                             ...     ...   ...
# 40427  Clothing_Shoes_and_Jewelry_5     4.0    OR
# 40428  Clothing_Shoes_and_Jewelry_5     5.0    CG
# 40429  Clothing_Shoes_and_Jewelry_5     2.0    OR
# 40430  Clothing_Shoes_and_Jewelry_5     1.0    CG
# 40431  Clothing_Shoes_and_Jewelry_5     5.0    OR
#
#                                                    text_
# 0      Love this!  Well made, sturdy, and very comfor...
# 1      love it, a great upgrade from the original.  I...
# 2      This pillow saved my back. I love the look and...
# 3      Missing information on how to use it, but it i...
# 4      Very nice set. Good quality. We have had the s...
# ...

# %%
# Dropping unncesessary columns

df.drop(['category' , 'rating'] , axis = 1 , inplace = True)

# %%
df

#Showing our dataframe
# Out:
#       label                                              text_
# 0        CG  Love this!  Well made, sturdy, and very comfor...
# 1        CG  love it, a great upgrade from the original.  I...
# 2        CG  This pillow saved my back. I love the look and...
# 3        CG  Missing information on how to use it, but it i...
# 4        CG  Very nice set. Good quality. We have had the s...
# ...     ...                                                ...
# 40427    OR  I had read some reviews saying that this bra r...
# 40428    CG  I wasn't sure exactly what it would be. It is ...
# 40429    OR  You can wear the hood by itself, wear it with ...
# 40430    CG  I liked nothing about this dress. The only rea...
# 40431    OR  I work in the wedding industry and have to wor...
#
# [40432 rows x 2 columns]

# %%
df.replace({'label':{'CG':1, 'OR':0}}, inplace = True)

#Here in label, 1 represent fake data and 0 represents reviews given by a user

# %%
messages = df.copy()

# Here we have created copy of our dataframe

# %%
# Data Cleaning and Preprocessing

# Importing Necessary Libraries

import re
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')

from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...

# %%
#Creating Object of WordNet Lemmatizer
wordnet = WordNetLemmatizer()
corpus = []   #Created a List named corpus.


for i in range(0,len(messages)):
    print(i)
    review = re.sub('[^a-zA-Z]' , ' ' , messages['text_'][i]) # Using Regex Function to replace digits and Special chracters with space
    review = review.lower() #converting all the reviews into lower case
    review = review.split() # splitting the reviews (by default space)
    
    # using list comprehension to compare the words which are not in stopword english library and appending them into list corpus.
    review = [wordnet.lemmatize(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    corpus.append(review)
# Out:
# Streaming output truncated to the last 5000 lines.
# 35432
# 35433
# 35434
# 35435
# 35436
# 35437
# 35438
# 35439
# 35440
# 35441
# 35442
# 35443
# 35444
# 35445
# 35446
# 35447
# 35448
# 35449
# 35450
# 35451
# 35452
# 35453
# 35454
# 35455
# 35456
# 35457
# 35458
# 35459
# 35460
# 35461
# 35462
# 35463
# 35464
# 35465
# 35466
# 35467
# 35468
# 35469
# 35470
# 35471
# 35472
# 35473
# 35474
# 35475
# 35476
# 35477
# 35478
# 35479
# 35480
# 35481
# 35482
# 35483
# 35484
# 35485
# 35486
# 35487
# 35488
# 35489
# 35490
# 35491
# 35492
# 35493
# 35494
# 35495
# 35496
# 35497
# 35498
# 35499
# 35500
# 35501
# 35502
# 35503
# 35504
# 35505
# 35506
# 35507
# 35508
# 35509
# 35510
# 35511
# 35512
# 35513
# 35514
# 35515
# 35516
# 35517
# 35518
# 35519
# 35520
# 35521
# 35522
# 35523
# 35524
# 35525
# 35526
# 35527
# 35528
# 35529
# 35530
# 35531
# 35532
# 35533
# 35534
# 35535
# 35536
# 35537
# 35538
# 35539
# 35540
# 35541
# 35542
# 35543
# 35544
# 35545
# 35546
# 35547
# 35548
# 35549
# ...

# %%
corpus # displaying list corpus
# Out:
# ['love well made sturdy comfortable love pretty',
#  'love great upgrade original mine couple year',
#  'pillow saved back love look feel pillow',
#  'missing information use great product price',
#  'nice set good quality set two month',
#  'wanted different flavor',
#  'perfect touch thing wish little space',
#  'done fit well look great love smoothness edge extra',
#  'great big number easy read thing like size',
#  'son love comforter well made also baby',
#  'advertised th one problem really',
#  'handy one kid tool included package one',
#  'someone say oriental great product',
#  'flimsy quality would expect piece furniture',
#  'make may tea stirring problem kind hard put',
#  'absolutely adorable excellent price wooden one month',
#  'love perfect size entire family good quality',
#  'look beautiful nice problem really mesh one',
#  'exactly would expect love look feel pillow',
#  'star would highly recommend item love blanket',
#  'great little egg masher month',
# ...

# %%
df['text_'] = corpus # created a new column text_ and added the data of corpus into the column

# %%
df.to_csv('fake_data_cleaned.csv') #converting dataframe into csv file.
